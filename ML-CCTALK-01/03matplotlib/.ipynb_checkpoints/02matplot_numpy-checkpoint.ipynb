# %% [markdown]
# # 画图：numpy矩阵+函数

# %% [markdown]
# ## 1 与numpy矩阵

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
N01 =50
x01 = np.random.rand(N01)
y01 = np.random.rand(N01)
x01,y01
# Out:
# (array([ 0.61790006,  0.39969191,  0.65800072,  0.78131248,  0.40261231,
#          0.05277138,  0.9924725 ,  0.7030718 ,  0.44609607,  0.27467448,
#          0.27871855,  0.57754263,  0.31962412,  0.53900012,  0.84752098,
#          0.50464311,  0.34147186,  0.52746073,  0.96395633,  0.47223271,
#          0.95467434,  0.2580951 ,  0.62527745,  0.78632257,  0.50253993,
#          0.18400297,  0.3792396 ,  0.13082041,  0.5989498 ,  0.0860857 ,
#          0.00402687,  0.02053743,  0.8785636 ,  0.71490485,  0.43393983,
#          0.93009823,  0.99926456,  0.80973388,  0.64571624,  0.14855474,
#          0.84338414,  0.80012668,  0.88538575,  0.68927242,  0.77971654,
#          0.80690101,  0.30341724,  0.34942214,  0.3955193 ,  0.48326328]),
#  array([ 0.45155675,  0.11958477,  0.28429099,  0.6605065 ,  0.25975092,
#          0.10674996,  0.51883567,  0.7779333 ,  0.04801771,  0.38940817,
#          0.39366166,  0.4424473 ,  0.4841856 ,  0.56755967,  0.66416067,
#          0.33465359,  0.44694118,  0.97682079,  0.06448966,  0.94409716,
#          0.73326623,  0.40697286,  0.20641775,  0.26516125,  0.62400353,
#          0.76535838,  0.87382007,  0.04676991,  0.87227741,  0.1972831 ,
#          0.84753591,  0.82926774,  0.26756425,  0.6413655 ,  0.36451069,
#          0.52169457,  0.7945917 ,  0.17763849,  0.58776466,  0.67530502,
#          0.44409786,  0.05289244,  0.97561049,  0.90534064,  0.78966624,
#          0.39477248,  0.51846206,  0.175793  ,  0.28443102,  0.2295208 ]))

# %%
plt.figure(figsize=[14,10])
plt.scatter(x01,y01,c=y01)
plt.xlabel("numpy")
plt.show()

# %% [markdown]
# ## 2.1 函数

# %%
x02=x01*np.pi**2
x02
# Out:
# array([ 6.09842918,  3.94480106,  6.49420684,  7.71124508,  3.97362422,
#         0.52083268,  9.79531099,  6.93904057,  4.40279173,  2.71092849,
#         2.75084187,  5.70011731,  3.15456366,  5.31971795,  8.36469679,
#         4.98062784,  3.37019215,  5.20582875,  9.51386763,  4.66075006,
#         9.42225804,  2.54729649,  6.17124106,  7.76069266,  4.95987028,
#         1.81603652,  3.74294487,  1.29114568,  5.91139763,  0.84963183,
#         0.03974357,  0.20269628,  8.6710752 ,  7.05582801,  4.2828145 ,
#         9.17970159,  9.86234586,  7.99175311,  6.37296381,  1.46617648,
#         8.32386785,  7.89693378,  8.73840708,  6.80284612,  7.69549377,
#         7.96379379,  2.99460812,  3.44865825,  3.90361904,  4.76961735])

# %%
plt.figure(figsize=[14,10])
plt.scatter(x02,y01,c=x01)
plt.xlabel("function")
plt.show()

# %% [markdown]
# ### 2.2 颜色随机，大小随机

# %%
colors01 = np.random.rand(N01)
area01 = np.pi * (15 * np.random.rand(N01))**2
plt.figure(figsize=[14,10])
plt.scatter(x01, y01, s=area01, c=colors01, alpha=0.5)
plt.show()
